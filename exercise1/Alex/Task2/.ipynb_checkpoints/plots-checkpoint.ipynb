# %%
import glob 
import numpy as np
files_250 = glob.glob("data/res_250/*.csv") 
files_2000 = glob.glob("data/res_2000/*.csv")
files_4000 = glob.glob("data/res_4000/*.csv")
files_8000 = glob.glob("data/res_8000/*.csv")

# %%
import pandas as pd
import os
import seaborn as sns
data_250 = pd.DataFrame()
data_1000 = pd.DataFrame()

for file in files_250:
    if file.endswith('.csv'):
        df = pd.read_csv(file)
        data_250 = data_250.append(df, ignore_index=True)
        
for file in files_1000:
    if file.endswith('.csv'):
        df = pd.read_csv(file)
        data_1000 = data_1000.append(df, ignore_index=True)

# %%
d = np.arange(1,len(data_1000)+1)
data_1000
# Out:
#     iterations    runtime  runtime/iter  norm2res_gloabl  normMres_global  \
# 0        10000   1.740660      0.000174          27634.3          94.2259
# 1        10000   1.936740      0.000194          27634.3          94.2259
# 2        10000   4.738910      0.000474          27634.3          94.2259
# 3        10000   2.152860      0.000215          27634.3          94.2259
# 4        10000   2.352680      0.000235          27634.3          94.2259
# 5        10000  11.049700      0.001105          27634.3          94.2259
# 6        10000   2.452260      0.000245          27634.3          94.2259
# 7        10000   2.131580      0.000213          27634.3          94.2259
# 8        10000   7.564280      0.000756          27634.3          94.2259
# 9        10000   2.571660      0.000257          27634.3          94.2259
# 10       10000   5.627150      0.000563          27634.3          94.2259
# 11       10000   2.995320      0.000300          27634.3          94.2259
# 12       10000  22.686900      0.002268          27634.3          94.2259
# 13       10000   1.505530      0.000151          27634.3          94.2259
# 14       10000   2.155270      0.000216          27634.3          94.2259
# 15       10000   2.541500      0.000254          27634.3          94.2259
# 16       10000   1.726720      0.000173          27634.3          94.2259
# 17       10000   3.538050      0.000354          27634.3          94.2259
# 18       10000   1.704940      0.000170          27634.3          94.2259
# 19       10000   2.373920      0.000237          27634.3          94.2259
# 20       10000   2.890070      0.000289          27634.3          94.2259
# 21       10000   2.130460      0.000213          27634.3          94.2259
# 22       10000   1.914840      0.000191          27634.3          94.2259
# 23       10000   3.191540      0.000319          27634.3          94.2259
# 24       10000   4.035330      0.000403          27634.3          94.2259
# 25       10000   2.438340      0.000244          27634.3          94.2259
# 26       10000   2.239950      0.000224          27634.3          94.2259
# 27       10000   2.313150      0.000231          27634.3          94.2259
# 28       10000   2.385900      0.000239          27634.3          94.2259
# 29       10000   1.961560      0.000196          27634.3          94.2259
# 30       10000   1.839260      0.000184          27634.3          94.2259
# 31       10000   2.691480      0.000269          27634.3          94.2259
# 32       10000   2.889690      0.000289          27634.3          94.2259
# 33       10000   2.020420      0.000202          27634.3          94.2259
# 34       10000   1.998370      0.000200          27634.3          94.2259
# 35       10000   2.019550      0.000202          27634.3          94.2259
# 36       10000   0.827695      0.000083          27634.3          94.2259
# 37       10000   2.356710      0.000236          27634.3          94.2259
# 38       10000   2.421900      0.000242          27634.3          94.2259
# 39       10000   3.023530      0.000302          27634.3          94.2259
#
#     norm2err_global  normMerr_global  Unnamed: 7
# 0         5272150.0          24504.8         NaN
# 1         5272150.0          24504.8         NaN
# 2         5272150.0          24504.8         NaN
# 3         5272150.0          24504.8         NaN
# 4         5272150.0          24504.8         NaN
# 5         5272150.0          24504.8         NaN
# 6         5272150.0          24504.8         NaN
# 7         5272150.0          24504.8         NaN
# 8         5272150.0          24504.8         NaN
# 9         5272150.0          24504.8         NaN
# 10        5272150.0          24504.8         NaN
# 11        5272150.0          24504.8         NaN
# 12        5272150.0          24504.8         NaN
# 13        5272150.0          24504.8         NaN
# 14        5272150.0          24504.8         NaN
# 15        5272150.0          24504.8         NaN
# 16        5272150.0          24504.8         NaN
# 17        5272150.0          24504.8         NaN
# 18        5272150.0          24504.8         NaN
# 19        5272150.0          24504.8         NaN
# 20        5272150.0          24504.8         NaN
# 21        5272150.0          24504.8         NaN
# 22        5272150.0          24504.8         NaN
# 23        5272150.0          24504.8         NaN
# 24        5272150.0          24504.8         NaN
# 25        5272150.0          24504.8         NaN
# 26        5272150.0          24504.8         NaN
# 27        5272150.0          24504.8         NaN
# 28        5272150.0          24504.8         NaN
# 29        5272150.0          24504.8         NaN
# 30        5272150.0          24504.8         NaN
# 31        5272150.0          24504.8         NaN
# 32        5272150.0          24504.8         NaN
# 33        5272150.0          24504.8         NaN
# 34        5272150.0          24504.8         NaN
# 35        5272150.0          24504.8         NaN
# 36        5272150.0          24504.8         NaN
# 37        5272150.0          24504.8         NaN
# 38        5272150.0          24504.8         NaN
# 39        5272150.0          24504.8         NaN

# %%
sns.lineplot(y="runtime", x=d[0:16], data=data_250[0:16])
#sns.lineplot(y="runtime", x=d, data=data_1000)

# %%
import pandas as pd
df = pd.DataFrame
df = pd.read_csv("localDom.csv")

# %%
df
